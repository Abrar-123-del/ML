# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df.head(3)
# Out:
#    year  per_capita_income
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income (US$)')
plt.scatter(df['year'], df['per_capita_income'], color='red', marker='+')

# %%
reg = LinearRegression()

# %%
reg.fit(df[['year']], df.per_capita_income)
# Out:
# LinearRegression()

# %%
# %matplotlib inline
plt.xlabel('year', fontsize=20)
plt.ylabel('income (US$)', fontsize=20)
plt.scatter(df['year'], df['per_capita_income'], color='red', marker='+')
plt.plot(df.year, reg.predict(df[['year']]), color='blue')

# %%
year_df = pd.DataFrame({'year': [1980]})
predicted_income = reg.predict(year_df)
print(f"Predicted per capita income for the year 1980 is {predicted_income[0]}")
# Out:
# Predicted per capita income for the year 1980 is 8150.091085509164
