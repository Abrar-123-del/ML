# %%
import pandas as pd

# %%
df = pd.read_csv("heart.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_Sex = LabelEncoder()
le_ChestPainType = LabelEncoder()
le_RestingECG = LabelEncoder()
le_ExerciseAngina = LabelEncoder()
le_ST_Slope = LabelEncoder()

# %%
df['Sex_n'] = le_Sex.fit_transform(df['Sex'])
df['ChestPainType_n'] = le_ChestPainType.fit_transform(df['ChestPainType'])
df['RestingECG_n'] = le_RestingECG.fit_transform(df['RestingECG'])
df['ExerciseAngina_n'] = le_ExerciseAngina.fit_transform(df['ExerciseAngina'])
df['ST_Slope_n'] = le_ST_Slope.fit_transform(df['ST_Slope'])

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Sex_n  ChestPainType_n  \
# 0              N      0.0       Up             0      1                1
# 1              N      1.0     Flat             1      0                2
# 2              N      0.0       Up             0      1                1
# 3              Y      1.5     Flat             1      0                0
# 4              N      0.0       Up             0      1                2
#
#    RestingECG_n  ExerciseAngina_n  ST_Slope_n
# ...

# %%
df_n = df.drop(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], axis='columns')

# %%
df_n
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#      Sex_n  ChestPainType_n  RestingECG_n  ExerciseAngina_n  ST_Slope_n
# ...

# %%
y = df_n['HeartDisease']
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(0.95)

# %%
X_pca = pca.fit_transform(df_n.drop('HeartDisease', axis='columns'))

# %%
X_pca.shape
# Out:
# (918, 2)

# %%
X_pca
# Out:
# array([[ 92.31094761,  29.44092723],
#        [-17.14271772,  13.75128639],
#        [ 81.90549795, -38.22744601],
#        ...,
#        [-69.00407582, -17.3379013 ],
#        [ 39.207459  ,  33.59828595],
#        [-21.43666353,  37.22417628]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.92021836, 0.04913303])

# %%
pca.n_components_
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=2)

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
model_1 = SVC()
model_1.fit(X_train, y_train)
model_1.score(X_test, y_test)
# Out:
# 0.717391304347826

# %%
model_2 = LogisticRegression()
model_2.fit(X_train, y_train)
model_2.score(X_test, y_test)
# Out:
# 0.6847826086956522

# %%
model_3 = RandomForestClassifier()
model_3.fit(X_train, y_train)
model_3.score(X_test, y_test)
# Out:
# 0.7065217391304348
