# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
# Plotting a bar chart for 'salary' distribution
salary_counts = df['salary'].value_counts()

plt.figure(figsize=(10, 6))
salary_counts.plot(kind='bar', color=['blue', 'orange', 'green'])
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
department_counts = df['Department'].value_counts()

plt.figure(figsize=(12, 8))
department_counts.plot(kind='bar', color='purple')
plt.title('Department Distribution')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['satisfaction_level', 'last_evaluation', 'number_project', 'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years', 'Department', 'salary']], df['average_montly_hours'], test_size=0.2)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10552\3122369064.py in ?()
#       1 model = LogisticRegression()
# ----> 2 model.fit(X_train, y_train)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1219             _dtype = np.float64
#    1220         else:
#    1221             _dtype = [np.float64, np.float32]
#    1222
# -> 1223         X, y = self._validate_data(
# ...
